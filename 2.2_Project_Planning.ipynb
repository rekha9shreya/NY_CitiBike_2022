# %% [markdown]
# # Task 2.2 Project Planning and Sourcing Data With an API

# %% [markdown]
# ## Import and Install Libraries

# %%
# %pip install pandas numpy
# Out:
# ...
#
#   Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# ...

# %%
# %pip install requests
# Out:
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata (34 kB)
# ...
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# ...
#   Using cached urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# ...
#   Using cached certifi-2024.6.2-py3-none-any.whl.metadata (2.2 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached certifi-2024.6.2-py3-none-any.whl (164 kB)
# Using cached charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl (100 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import os
import requests
import json
from datetime import datetime

# %%
# Create a list with all files in the folder using a list compehension

folderpath = r"C:\Users\bhimc\Documents\Work local\NY_CitiBike_2022\NY_CitiBike_2022_Data"
filepaths  = [os.path.join(folderpath, name) for name in os.listdir(folderpath)]

# %%
filepaths
# Out:
# ['C:\\Users\\bhimc\\Documents\\Work local\\NY_CitiBike_2022\\NY_CitiBike_2022_Data\\202201-citibike-tripdata.csv',
#  'C:\\Users\\bhimc\\Documents\\Work local\\NY_CitiBike_2022\\NY_CitiBike_2022_Data\\202202-citibike-tripdata.csv',
#  'C:\\Users\\bhimc\\Documents\\Work local\\NY_CitiBike_2022\\NY_CitiBike_2022_Data\\202203-citibike-tripdata.csv',
#  'C:\\Users\\bhimc\\Documents\\Work local\\NY_CitiBike_2022\\NY_CitiBike_2022_Data\\202204-citibike-tripdata.csv',
#  'C:\\Users\\bhimc\\Documents\\Work local\\NY_CitiBike_2022\\NY_CitiBike_2022_Data\\202205-citibike-tripdata.csv',
#  'C:\\Users\\bhimc\\Documents\\Work local\\NY_CitiBike_2022\\NY_CitiBike_2022_Data\\202206-citbike-tripdata.csv',
#  'C:\\Users\\bhimc\\Documents\\Work local\\NY_CitiBike_2022\\NY_CitiBike_2022_Data\\202207-citbike-tripdata.csv',
#  'C:\\Users\\bhimc\\Documents\\Work local\\NY_CitiBike_2022\\NY_CitiBike_2022_Data\\202208-citibike-tripdata.csv',
# ...

# %%
# Read and concatenate all files simultaneously
df = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index = True)
# Out:
# C:\Users\bhimc\AppData\Local\Temp\ipykernel_4036\4167960515.py:2: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index = True)
# C:\Users\bhimc\AppData\Local\Temp\ipykernel_4036\4167960515.py:2: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index = True)
# C:\Users\bhimc\AppData\Local\Temp\ipykernel_4036\4167960515.py:2: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index = True)
# C:\Users\bhimc\AppData\Local\Temp\ipykernel_4036\4167960515.py:2: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index = True)
# ...

# %% [markdown]
# ### The code creates a list of file paths by merging a given folder path with each element in that folder. It uses os.listdir(folderpath) to get a list of all file and directory names in the folder, and then os.path.join(folderpath, name) to combine the folder path with each entry name, to make sure the path format is correct for the OS. The variable filepaths now contains a list of complete paths for all folder items.

# %% [markdown]
# ### I kept running into memory errors when I tried to merge the data at the end, so I will change some of the variables from 64 byte to 32 byte.

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
# Convert data types to float32
df['start_lat'] = df['start_lat'].astype('float32')
df['start_lng'] = df['start_lng'].astype('float32')
df['end_lat'] = df['end_lat'].astype('float32')
df['end_lng'] = df['end_lng'].astype('float32')

# %%
#check conversion
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float32
# start_lng             float32
# end_lat               float32
# end_lng               float32
# member_casual          object
# dtype: object

# %%
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  55262E4365A955A2   classic_bike  2022-01-18 08:23:52  2022-01-18 08:28:18
# 1  D272F1B15D841EC0   classic_bike  2022-01-21 09:03:22  2022-01-21 09:05:44
# 2  D1FCEF55EB4A807F   classic_bike  2022-01-22 14:28:32  2022-01-22 14:53:18
# 3  E9CBDC6A0162C068  electric_bike  2022-01-19 14:49:47  2022-01-19 14:54:02
# 4  2177A5B57326CE9B  electric_bike  2022-01-16 14:36:06  2022-01-16 14:44:06
#
#         start_station_name start_station_id           end_station_name  \
# 0  Boerum Pl\t& Pacific St          4488.09  Clinton St & Joralemon St
# 1          E 12 St & Ave C          5616.08         E 10 St & Avenue A
# 2          W 21 St & 6 Ave          6140.05           W 44 St & 11 Ave
# 3           38 St & 30 Ave          6850.01       Crescent St & 30 Ave
# 4   Pacific St & Nevins St          4362.04    Clinton St & Tillary St
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual
# ...

# %% [markdown]
# ## Get Weather data using NOAA's API

# %%
# Define your NOAA token - type yours in here! 

Token = 'qQyUGMkgWcFDJDFtGQdAMAwIIIMVllEY'

# %%
# Get the API 

r = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TAVG&limit=1000&stationid=GHCND:USW00014732&startdate=2022-01-01&enddate=2022-12-31', headers={'token':Token})

# %%
# Load the API response as a json

d = json.loads(r.text)

# %%
d
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 365, 'limit': 1000}},
#  'results': [{'date': '2022-01-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 116},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 114},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 14},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': -27},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 32},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 49},
#   {'date': '2022-01-07T00:00:00',
# ...

# %%
# Secure all items in the response that correspond to TAVG

avg_temps = [item for item in d['results'] if item['datatype']=='TAVG']

# %%
# Get only the date field from all average temperature readings

dates_temp = [item['date'] for item in avg_temps]

# %%
# Get the temperature from all average temperature readings

temps = [item['value'] for item in avg_temps]

# %%
temps
# Out:
# [116,
#  114,
#  14,
#  -27,
#  32,
#  49,
#  7,
#  -25,
#  14,
#  16,
#  -54,
#  -19,
#  40,
#  48,
#  -67,
#  -80,
#  39,
#  18,
#  32,
#  51,
#  -60,
#  -59,
#  -7,
#  -2,
#  36,
#  -23,
#  -42,
#  1,
#  -48,
#  -71,
#  -34,
#  -17,
#  23,
#  64,
#  58,
#  -28,
#  -48,
#  5,
#  41,
#  28,
#  63,
#  86,
#  118,
#  28,
#  -43,
#  -47,
#  16,
#  116,
#  99,
#  1,
#  -26,
#  41,
#  56,
#  144,
#  11,
#  8,
#  -11,
#  24,
#  8,
#  26,
#  77,
#  56,
#  -19,
#  31,
#  96,
#  182,
#  87,
#  32,
#  40,
#  72,
#  51,
#  -23,
#  53,
#  116,
#  136,
#  82,
#  139,
#  131,
#  143,
#  104,
#  107,
#  72,
#  57,
#  96,
#  104,
#  59,
#  -15,
#  -12,
#  26,
#  99,
#  131,
#  72,
#  70,
#  76,
#  97,
#  86,
#  91,
#  128,
#  114,
#  86,
#  88,
#  134,
#  154,
#  163,
#  157,
#  157,
#  83,
#  79,
#  76,
#  94,
#  106,
#  146,
#  133,
#  128,
#  104,
#  115,
#  116,
#  82,
#  104,
#  129,
#  136,
#  121,
#  124,
#  120,
#  172,
#  148,
#  100,
#  104,
#  135,
#  154,
#  161,
#  171,
#  160,
# ...

# %%
# Put the results in a dataframe

df_temp = pd.DataFrame()

# %%
# Get only date and cast it to date time; convert temperature from tenths of Celsius to normal Celsius

df_temp['date'] = [datetime.strptime(d, "%Y-%m-%dT%H:%M:%S") for d in dates_temp]
df_temp['avgTemp'] = [float(v)/10.0 for v in temps]

# %%
df_temp.tail()
# Out:
#           date  avgTemp
# 360 2022-12-27     -0.7
# 361 2022-12-28      3.4
# 362 2022-12-29      6.4
# 363 2022-12-30      9.3
# 364 2022-12-31      8.2

# %%
df.shape
# Out:
# (30689921, 13)

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float32
# start_lng             float32
# end_lat               float32
# end_lng               float32
# member_casual          object
# dtype: object

# %%
df['start_time'] = pd.to_datetime(df['started_at'], dayfirst = True)
# Out:
# C:\Users\bhimc\AppData\Local\Temp\ipykernel_4036\1746222128.py:1: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df['start_time'] = pd.to_datetime(df['started_at'], dayfirst = True)

# %%
df['date'] = pd.to_datetime(df['start_time'], format='%Y-%m-%d').dt.date

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
# %%time
df_merged = df.merge(df_temp, how = 'left', on = 'date', indicator = True)
# Out:
# CPU times: total: 2min 11s
# Wall time: 25min 51s

# %%
df_merged.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  55262E4365A955A2   classic_bike  2022-01-18 08:23:52  2022-01-18 08:28:18
# 1  D272F1B15D841EC0   classic_bike  2022-01-21 09:03:22  2022-01-21 09:05:44
# 2  D1FCEF55EB4A807F   classic_bike  2022-01-22 14:28:32  2022-01-22 14:53:18
# 3  E9CBDC6A0162C068  electric_bike  2022-01-19 14:49:47  2022-01-19 14:54:02
# 4  2177A5B57326CE9B  electric_bike  2022-01-16 14:36:06  2022-01-16 14:44:06
#
#         start_station_name start_station_id           end_station_name  \
# 0  Boerum Pl\t& Pacific St          4488.09  Clinton St & Joralemon St
# 1          E 12 St & Ave C          5616.08         E 10 St & Avenue A
# 2          W 21 St & 6 Ave          6140.05           W 44 St & 11 Ave
# 3           38 St & 30 Ave          6850.01       Crescent St & 30 Ave
# 4   Pacific St & Nevins St          4362.04    Clinton St & Tillary St
#
# ...

# %%
df_merged['_merge'].value_counts(dropna=False)
# Out:
# _merge
# both          30689921
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_merged.to_csv('NY_CityBike_2022.csv')
